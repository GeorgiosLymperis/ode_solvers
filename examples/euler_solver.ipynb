# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from ode_solvers import solvers

# %%
function = lambda t, y: 10
y0 = 1
euler = solvers.Euler(function)
result = euler.solve(y0)
euler.plot_solution()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='t', ylabel='y'>)
